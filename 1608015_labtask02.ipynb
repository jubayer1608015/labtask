# %% [markdown]
# <a href="https://colab.research.google.com/github/jubayer1608015/labtask/blob/main/1608015_labtask02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment Name: Exploring Different Types of Regression
#
# Course No: ETE 456
#
# Name: Khondokar Jubayer Rahman
# ID: 1608015
#
# Objective
#
# 1.To apply different regression algorithms in real world dataset.
#
# Task
#
# Prediction of Insurance Costs

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing The Libraries

# %%
import numpy as np        
import pandas as pd     
import matplotlib.pyplot as plt

# %%
# Download the data
# !wget -O insurance.csv https://www.dropbox.com/s/mwgqgjbmfw0xa5p/insurance.csv?dl=0
# Out:
# --2021-12-21 08:07:49--  https://www.dropbox.com/s/mwgqgjbmfw0xa5p/insurance.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/mwgqgjbmfw0xa5p/insurance.csv [following]
# --2021-12-21 08:07:49--  https://www.dropbox.com/s/raw/mwgqgjbmfw0xa5p/insurance.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc75618bc07f2636a1b777c19390.dl.dropboxusercontent.com/cd/0/inline/BcSj3X_PYUeWAmgcpg2zn4c0KJHqXO1otohQcDxum82l7yV2G71ntBhbOrRc764UHaHDb2jD7LIfYiXlXNGqYoXxzRIAAPBJ-EIZQx5_L1wCIwlthFrs9ypzlynQundxX72tSMFMNBWuHp2_26IMPsBV/file# [following]
# --2021-12-21 08:07:49--  https://uc75618bc07f2636a1b777c19390.dl.dropboxusercontent.com/cd/0/inline/BcSj3X_PYUeWAmgcpg2zn4c0KJHqXO1otohQcDxum82l7yV2G71ntBhbOrRc764UHaHDb2jD7LIfYiXlXNGqYoXxzRIAAPBJ-EIZQx5_L1wCIwlthFrs9ypzlynQundxX72tSMFMNBWuHp2_26IMPsBV/file
# Resolving uc75618bc07f2636a1b777c19390.dl.dropboxusercontent.com (uc75618bc07f2636a1b777c19390.dl.dropboxusercontent.com)... 162.125.6.15, 2620:100:6017:15::a27d:20f
# Connecting to uc75618bc07f2636a1b777c19390.dl.dropboxusercontent.com (uc75618bc07f2636a1b777c19390.dl.dropboxusercontent.com)|162.125.6.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55628 (54K) [text/plain]
# Saving to: ‘insurance.csv’
#
# insurance.csv       100%[===================>]  54.32K  --.-KB/s    in 0.09s
#
# 2021-12-21 08:07:50 (577 KB/s) - ‘insurance.csv’ saved [55628/55628]

# %%
dataset = pd.read_csv('insurance.csv')
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Now splitting the dataset into independent and dependent variables. Independent are the features which are used for prediction. Dependent is the target which will be predicted.

# %%
features = dataset[['age'	,'sex',	'bmi','children','smoker','region']]  # for independent
target = dataset[['charges']]   # for dependent

# %%
features
# Out:
#       age     sex     bmi  children smoker     region
# 0      19  female  27.900         0    yes  southwest
# 1      18    male  33.770         1     no  southeast
# 2      28    male  33.000         3     no  southeast
# 3      33    male  22.705         0     no  northwest
# 4      32    male  28.880         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 1333   50    male  30.970         3     no  northwest
# 1334   18  female  31.920         0     no  northeast
# 1335   18  female  36.850         0     no  southeast
# 1336   21  female  25.800         0     no  southwest
# 1337   61  female  29.070         0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
target
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# Taking Care of Missing Data
#
# Here 'sklearn' means sckit learn which is a package used for machine learning model. It contains many libraries.
#
# preprocessing is a library which contains several classes,methods. From this library we import the Imputer class which will allow us to take care of the missing data

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy = "mean") # imputer is an object of Imputer class 
imputer = imputer.fit(features[['age','bmi','children']])

# %%
features[['age','bmi','children']]= imputer.transform(features[['age','bmi','children']])

# %%
features
# Out:
#        age     sex     bmi  children smoker     region
# 0     19.0  female  27.900       0.0    yes  southwest
# 1     18.0    male  33.770       1.0     no  southeast
# 2     28.0    male  33.000       3.0     no  southeast
# 3     33.0    male  22.705       0.0     no  northwest
# 4     32.0    male  28.880       0.0     no  northwest
# ...    ...     ...     ...       ...    ...        ...
# 1333  50.0    male  30.970       3.0     no  northwest
# 1334  18.0  female  31.920       0.0     no  northeast
# 1335  18.0  female  36.850       0.0     no  southeast
# 1336  21.0  female  25.800       0.0     no  southwest
# 1337  61.0  female  29.070       0.0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy = "mean") # imputer is an object of Imputer class 
imputer = imputer.fit(target[['charges']])

# %%
target[['charges']]= imputer.transform(target[['charges']])

# %%
target
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
features['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
features['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
features['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
features['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
features['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# Encoding Categorical Data
#
# One Hot Encoding
#
# One hot encoder is used to convert the categorical data into numerical, so that they can be used in prediction.

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
encoder=OneHotEncoder(sparse=False)
encoded_labels = pd.DataFrame (encoder.fit_transform(features[['sex','smoker','region']]))

# %%
encoded_labels.columns = encoder.get_feature_names(['sex','smoker','region'])
dataset= pd.concat([features, encoded_labels ], axis=1)

# %%
dataset
# Out:
#        age     sex  ...  region_southeast  region_southwest
# 0     19.0  female  ...               0.0               1.0
# 1     18.0    male  ...               1.0               0.0
# 2     28.0    male  ...               1.0               0.0
# 3     33.0    male  ...               0.0               0.0
# 4     32.0    male  ...               0.0               0.0
# ...    ...     ...  ...               ...               ...
# 1333  50.0    male  ...               0.0               0.0
# 1334  18.0  female  ...               0.0               0.0
# 1335  18.0  female  ...               1.0               0.0
# 1336  21.0  female  ...               0.0               1.0
# 1337  61.0  female  ...               0.0               0.0
#
# [1338 rows x 14 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'sex_female',
#        'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
new_features = dataset[['age', 'sex_female', 'sex_male',
       'smoker_no', 'smoker_yes', 'bmi','children','region_northeast','region_northwest','region_southeast','region_southwest']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(new_features,target,test_size=0.1,random_state=73)
# random_state = 0 is select to get the same result

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1204, 11)
# (134, 11)

# %%
X_train
# Out:
#        age  sex_female  ...  region_southeast  region_southwest
# 204   46.0         0.0  ...               0.0               1.0
# 703   34.0         1.0  ...               0.0               0.0
# 24    37.0         0.0  ...               0.0               0.0
# 1222  50.0         0.0  ...               1.0               0.0
# 106   19.0         1.0  ...               0.0               1.0
# ...    ...         ...  ...               ...               ...
# 321   26.0         1.0  ...               0.0               0.0
# 323   57.0         0.0  ...               0.0               0.0
# 394   46.0         1.0  ...               0.0               0.0
# 146   46.0         0.0  ...               0.0               0.0
# 918   61.0         1.0  ...               0.0               1.0
#
# [1204 rows x 11 columns]

# %% [markdown]
# Fitting Multiple Linear Regression Model to Training Set
#
# Different types of Regression Algorithm
#
# Linear Regression (Univariate or Multivariate)
#
#  Support Vector Regression
#
#   Decision Tree Regression
#
#   Random Forest Regressrion

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train,y_train)

# Predicting the Test Set Results
y_pred = regressor.predict(X_test)

# %%
y_test
# Out:
#           charges
# 803   38792.68560
# 263   36219.40545
# 196    5649.71500
# 694    3577.99900
# 37     2302.30000
# ...           ...
# 986    8410.04685
# 258   11520.09985
# 49    38709.17600
# 1079  15161.53440
# 1228  10594.22570
#
# [134 rows x 1 columns]

# %%
y_pred
# Out:
# array([[29669.37089159],
#        [28823.93374863],
#        [ 8166.09658616],
#        [ 6168.11407507],
#        [  799.60702066],
#        [25670.79275768],
#        [10536.29379753],
#        [11198.2978864 ],
#        [11390.55535189],
#        [39110.75057103],
#        [13060.42139099],
#        [30971.7066379 ],
#        [32032.91626116],
#        [ 3730.67672065],
#        [ 7855.42051837],
#        [32119.08962045],
#        [ 7231.36619798],
#        [31931.03209881],
#        [ 2585.94975287],
#        [33812.93660703],
#        [ 8146.96517646],
#        [ 9369.733045  ],
#        [  -51.95234889],
#        [13905.72688798],
#        [ 5713.93107343],
#        [ 2394.45462181],
#        [34332.16736543],
#        [32411.63659129],
#        [ 1047.51668472],
#        [ 5649.38794692],
#        [15681.52113764],
#        [ 4369.01727831],
#        [35205.59745212],
#        [ 6873.63302937],
#        [ 3710.93323686],
#        [29040.04869295],
#        [15218.81701735],
#        [ 8843.2776472 ],
#        [16744.76717616],
#        [-1006.31185285],
#        [26674.78098691],
#        [30759.7406943 ],
#        [12657.31881629],
#        [15400.42349058],
#        [10525.11371039],
#        [10190.723362  ],
#        [ 9751.13287823],
#        [ 5121.0927894 ],
#        [13332.65147777],
#        [11684.73655932],
#        [14468.63835764],
#        [ 5262.37456004],
#        [ 5192.1615496 ],
#        [ 4826.03358253],
#        [36808.25814583],
#        [10562.45733184],
#        [ 7959.87820739],
#        [ 5618.55303409],
#        [ 6195.38800438],
#        [ 3769.40786461],
#        [33931.60886142],
#        [ 8961.28872523],
#        [13420.81774751],
#        [31058.57610382],
#        [14231.44377709],
#        [37845.55378154],
#        [ 9446.11602318],
#        [10407.00544079],
#        [28331.37486362],
#        [13634.27532541],
#        [27509.64553949],
#        [ 2217.08839304],
#        [ 2819.12032666],
#        [12799.21081622],
#        [16769.25958674],
#        [16033.28620951],
#        [36190.2253015 ],
#        [12056.46201253],
#        [ 6951.33836027],
#        [11722.59377372],
#        [ 5525.5392651 ],
#        [ 9857.95456939],
#        [34915.51534972],
#        [37086.09966385],
#        [  604.57125354],
#        [ 4577.66292657],
#        [ 4613.62916597],
#        [ 2795.90058111],
#        [14665.92144149],
#        [26230.54827376],
#        [ 5671.5987277 ],
#        [ 6913.41417653],
#        [ 2701.33222963],
#        [12311.19605289],
#        [ 1591.99091915],
#        [11864.96573784],
#        [30981.25687757],
#        [10219.63979977],
#        [12035.43791563],
#        [28050.72424772],
#        [ 8257.69470683],
#        [10760.64534313],
#        [11303.37631857],
#        [11120.64961619],
#        [ 8409.77199791],
#        [28673.55489421],
#        [32384.8881695 ],
#        [ 7786.95864051],
#        [14340.37448443],
#        [30823.46560518],
#        [ 5633.70468428],
#        [ 4606.5530492 ],
#        [10482.04121389],
#        [ 8446.05576961],
#        [33842.8967367 ],
#        [ 5088.16106858],
#        [12595.71346958],
#        [ 8152.97813589],
#        [12687.60511067],
#        [35311.44433059],
#        [ 2853.67116611],
#        [ 7083.28549527],
#        [ 5335.0530988 ],
#        [ 8505.11561697],
#        [28998.62597329],
#        [15138.81001615],
#        [ 9528.59492965],
#        [ 7990.48401447],
#        [12198.82717219],
#        [10174.98158159],
#        [10804.27485894],
#        [32372.04747249],
#        [15800.13957683],
#        [12927.14652748]])

# %% [markdown]
# Evaluation Metrices
#
# Mean Absolute Error (MAE) Mean Squared Error (MSE) R-Squared Error

# %%
from sklearn.metrics import mean_absolute_error

# MAE

mean_absolute_error(y_test, y_pred)
# Out:
# 4640.5878994470695

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_pred)
# Out:
# 46853261.17967038

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.7113969820315541

# %%
dataset
# Out:
#        age     sex  ...  region_southeast  region_southwest
# 0     19.0  female  ...               0.0               1.0
# 1     18.0    male  ...               1.0               0.0
# 2     28.0    male  ...               1.0               0.0
# 3     33.0    male  ...               0.0               0.0
# 4     32.0    male  ...               0.0               0.0
# ...    ...     ...  ...               ...               ...
# 1333  50.0    male  ...               0.0               0.0
# 1334  18.0  female  ...               0.0               0.0
# 1335  18.0  female  ...               1.0               0.0
# 1336  21.0  female  ...               0.0               1.0
# 1337  61.0  female  ...               0.0               0.0
#
# [1338 rows x 14 columns]

# %% [markdown]
# Feature Scaling
#
# It is necessary because sometimes a large value in the variable can dominate the small value.

# %%
from sklearn.preprocessing import StandardScaler
X_sc = StandardScaler()
y_sc = StandardScaler()
X_train_new = X_sc.fit_transform(X_train[['age', 'sex_female', 'sex_male',
       'smoker_no', 'smoker_yes', 'bmi','children','region_northeast','region_northwest','region_southeast','region_southwest']])
X_test_new = X_sc.transform(X_test[['age', 'sex_female', 'sex_male',
       'smoker_no', 'smoker_yes', 'bmi','children','region_northeast','region_northwest','region_southeast','region_southwest']])
y_train_new = y_sc.fit_transform(y_train[['charges']])
y_test_new = y_sc.transform(y_test[['charges']])

# %% [markdown]
# Support Vector Regression

# %%
from sklearn.svm import SVR 

regressor = SVR(kernel = 'linear')
regressor.fit(X_train_new,y_train_new)
# Out:
# SVR(kernel='linear')

# %%
y_pred = regressor.predict(X_test_new)

# %%
r2_score(y_test_new, y_pred)
# Out:
# 0.7619821999423445

# %% [markdown]
# Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor


regressor = DecisionTreeRegressor(random_state = 73)
regressor.fit(X_train_new,y_train_new)
# Out:
# DecisionTreeRegressor(random_state=73)

# %%
y_pred = regressor.predict(X_test_new)
r2_score(y_test_new, y_pred)
# Out:
# 0.7599587544627731

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators = 12,random_state = 73) # n estiamator is the number of decision trees
regressor.fit(X_train_new,y_train_new)
# Out:
# RandomForestRegressor(n_estimators=12, random_state=73)

# %%
y_pred = regressor.predict(X_test_new)
r2_score(y_test_new, y_pred)
# Out:
# 0.834483315682588

# %% [markdown]
# The R-square error for the regression are given below:
#
# Linear Regression :0.7113969820315541
#
# Support Vector Regression: 0.7619821999423445
#
# Decision Tree Regression:0.7599587544627731
#
# Random Forest Regressrion: 0.834483315682588
#
# In the dataset, Multivariate Linear Regression, Support Vector Regression, Decision Tree Regression, Random Forest Regressrion has been applied. For evaluating their performances R-square error evaluation matrix has been applied for all. From the values we can see that, R-square value for random forest regression is more close to 1 which is 0.85 than the others. So that, random forest regression gives better prediction in the dataset.
